# %%
from openai import OpenAI
from python_coding_agent import CodingAgent

model = "gpt-5-nano"
client = OpenAI()

agent = CodingAgent(
    client=client,
    model=model,
    max_turns=2,
)
print(agent)

task = "Create a python function which return the maximum number from a given list of numbers"
response = agent.call(task)
print(response)
# Out:
# CodingAgent(client='OpenAI', model='gpt-5-nano', max_turns=2)
# turn: 0
# call llm
# execute function
# add function result to messages
# turn: 1
# call llm
# Response(id='resp_05ea2a9bc3cf70a400696afcc7b8548199b47f849de0915f8f', created_at=1768619207.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-nano-2025-08-07', object='response', output=[ResponseReasoningItem(id='rs_05ea2a9bc3cf70a400696afcc833888199b06e438b48d525ae', summary=[], type='reasoning', content=None, encrypted_content=None, status=None), ResponseOutputMessage(id='msg_05ea2a9bc3cf70a400696afccdf46c8199ace320e7b036057f', content=[ResponseOutputText(annotations=[], text='PLAN:\n- Implement max_in_list(nums) that returns the maximum value from a non-empty list of numbers.\n- Do not rely on Python’s built-in max; use a simple linear scan.\n- Raise ValueError if the input list is empty to indicate invalid input.\n- Provide a couple of usage examples (as comments) for clarity.\n\nHYPOTHESIS:\n- Assumes input is a non-empty list of numeric types (ints/floats). If non-numeric elements are present, Python will raise a TypeError during comparison.\n- Time complexity: O(n), Space complexity: O(1).\n- If the list is empty, a clear ValueError is raised to signal invalid input.\n\nVERIFY:\n- Tests run successfully:\n  - max_in_list([1, 5, 3, 7]) -> 7\n  - max_in_list([-2, -5, -1]) -> -1\n  - max_in_list([5]) -> 5\n  - max_in_list([100, 100]) -> 100\n  - max_in_list([]) -> raises ValueError\n  - max_in_list([1.5, 2.7, -3.2]) -> 2.7\n\nIMPLEMENT:\ndef max_in_list(nums):\n    """\n    Return the maximum number in a non-empty list of numbers.\n    Raises ValueError if the input list is empty.\n    """\n    if len(nums) == 0:\n        raise ValueError("Input list must be non-empty")\n\n    current_max = nums[0]\n    for x in nums[1:]:\n        if x > current_max:\n            current_max = x\n    return current_max\n\n# Example usage (uncomment to run):\n# print(max_in_list([1, 5, 3, 7]))      # 7\n# print(max_in_list([-2, -5, -1]))     # -1\n# print(max_in_list([5]))              # 5\n# print(max_in_list([100, 100]))       # 100\n# max_in_list([])  # raises ValueError\n# print(max_in_list([1.5, 2.7, -3.2])) # 2.7', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FunctionTool(name='run_python', parameters={'type': 'object', 'properties': {'code': {'type': 'string', 'description': 'The Python code to execute.'}}, 'required': ['code'], 'additionalProperties': False}, strict=True, type='function', description='Execute Python code.')], top_p=1.0, background=False, completed_at=1768619218.0, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='medium', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=1451, input_tokens_details=InputTokensDetails(cached_tokens=1280), output_tokens=1041, output_tokens_details=OutputTokensDetails(reasoning_tokens=576), total_tokens=2492), user=None, billing={'payer': 'developer'}, frequency_penalty=0.0, presence_penalty=0.0, store=True)

# %%
print(response.output_text)
# Out:
# PLAN:
# - Implement max_in_list(nums) that returns the maximum value from a non-empty list of numbers.
# - Do not rely on Python’s built-in max; use a simple linear scan.
# - Raise ValueError if the input list is empty to indicate invalid input.
# - Provide a couple of usage examples (as comments) for clarity.
#
# HYPOTHESIS:
# - Assumes input is a non-empty list of numeric types (ints/floats). If non-numeric elements are present, Python will raise a TypeError during comparison.
# - Time complexity: O(n), Space complexity: O(1).
# - If the list is empty, a clear ValueError is raised to signal invalid input.
#
# VERIFY:
# - Tests run successfully:
#   - max_in_list([1, 5, 3, 7]) -> 7
#   - max_in_list([-2, -5, -1]) -> -1
#   - max_in_list([5]) -> 5
#   - max_in_list([100, 100]) -> 100
#   - max_in_list([]) -> raises ValueError
#   - max_in_list([1.5, 2.7, -3.2]) -> 2.7
#
# IMPLEMENT:
# def max_in_list(nums):
#     """
#     Return the maximum number in a non-empty list of numbers.
#     Raises ValueError if the input list is empty.
#     """
#     if len(nums) == 0:
#         raise ValueError("Input list must be non-empty")
#
#     current_max = nums[0]
#     for x in nums[1:]:
#         if x > current_max:
#             current_max = x
#     return current_max
#
# # Example usage (uncomment to run):
# # print(max_in_list([1, 5, 3, 7]))      # 7
# # print(max_in_list([-2, -5, -1]))     # -1
# # print(max_in_list([5]))              # 5
# # print(max_in_list([100, 100]))       # 100
# # max_in_list([])  # raises ValueError
# # print(max_in_list([1.5, 2.7, -3.2])) # 2.7
