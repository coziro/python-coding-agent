# %%
import logging

logger = logging.getLogger("python_coding_agent")
logger.setLevel(logging.INFO)
logger.handlers.clear()

handler = logging.StreamHandler()
handler.setFormatter(logging.Formatter("%(levelname)s:%(name)s:%(message)s"))
logger.addHandler(handler)

# %%
from python_coding_agent import CodingAgent


agent = CodingAgent(
    model="gpt-5-nano",
    max_turns=3,
)

task = "Create a python function which return the maximum number from a given list of numbers"
response = agent.call(task)

print("\n######## RESULT ########")
print(response.output_text)
# Out:
# INFO:python_coding_agent.agent:---- turn 1 (max: 3) ----
# INFO:python_coding_agent.agent:calling LLM
# INFO:python_coding_agent.agent:executing tool: run_python
# INFO:python_coding_agent.agent:---- turn 2 (max: 3) ----
# INFO:python_coding_agent.agent:calling LLM
# INFO:python_coding_agent.agent:no tool calls, done
# ######## RESULT ########
# PLAN:
# - Implement a function max_number(numbers) that returns the maximum value from a non-empty iterable of numbers.
# - Validate input: raise TypeError if numbers is None or not iterable; raise ValueError if empty.
# - Compute the maximum by iterating and tracking the current max (avoiding the built-in max to demonstrate the logic).
# - Ensure it supports ints and floats; let non-numeric contents raise TypeError during comparison.
#
# HYPOTHESIS:
# - For typical numeric lists, the function will return the correct maximum.
# - For an empty list, a ValueError will be raised.
# - For non-numeric contents, a TypeError will be raised due to invalid comparisons.
# - For non-iterable input, a TypeError will be raised.
#
# VERIFY:
# - I tested the approach with several cases:
#   - max_number([1, 2, 3]) -> 3
#   - max_number([-5, 0, 2.5]) -> 2.5
#   - max_number([10]) -> 10
#   - max_number([]) -> raises ValueError("numbers is empty")
#   - max_number(None) -> raises TypeError("numbers must be a non-empty iterable")
#   - max_number([1, 'a', 3]) -> raises TypeError due to invalid comparison
# - Results align with the expected behavior described above.
#
# IMPLEMENT:
# def max_number(numbers):
#     """Return the maximum value from a non-empty iterable of numbers.
#
#     Raises:
#       - TypeError: if numbers is None or not iterable
#       - ValueError: if numbers is empty
#     """
#     if numbers is None:
#         raise TypeError("numbers must be a non-empty iterable")
#     try:
#         nums = list(numbers)
#     except TypeError:
#         raise TypeError("numbers must be an iterable of numbers")
#     if len(nums) == 0:
#         raise ValueError("numbers is empty")
#
#     max_val = nums[0]
#     for x in nums[1:]:
#         if x > max_val:
#             max_val = x
#     return max_val
#
# This function will work for typical lists or other iterables of numeric types (ints, floats).
